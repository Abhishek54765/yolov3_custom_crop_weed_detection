# %%
cd /content/drive/MyDrive/weeds_detection
# Out:
# /content/drive/MyDrive/weeds_detection

# %%
# %cd /content/drive/MyDrive/weeds_detection/darknet
# Out:
# /content/drive/MyDrive/weeds_detection/darknet

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/weeds_detection/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/weeds_detection/darknet'...
# remote: Enumerating objects: 15298, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (9/9), done.
# remote: Total 15298 (delta 1), reused 6 (delta 0), pack-reused 15289
# Receiving objects: 100% (15298/15298), 13.67 MiB | 7.25 MiB/s, done.
# Resolving deltas: 100% (10380/10380), done.
# Checking out files: 100% (2044/2044), done.

# %%
# %cd /content/drive/MyDrive/weeds_detection/darknet
# Out:
# /content/drive/MyDrive/weeds_detection/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %%
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# %cd /content/drive/MyDrive/weeds_detection
# Out:
# /content/drive/MyDrive/weeds_detection

# %%
# !darknet/darknet detector train data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 4, batch = 64, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
# ^C

# %%
# !darknet/darknet detector train data/labelled_data.data darknet/cfg/yolov3_custom.cfg /content/drive/MyDrive/weeds_detection/backup/yolov3_custom_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 25336, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.714457), count: 4, class_loss = 0.783942, iou_loss = 0.260904, total_loss = 1.044846
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.037055, iou_loss = 0.000000, total_loss = 0.037055
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000638, iou_loss = 0.000000, total_loss = 0.000638
#  total_bbox = 25340, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.719497), count: 6, class_loss = 0.446352, iou_loss = 0.505744, total_loss = 0.952096
# ...

# %%
# !darknet/darknet detector test data/labelled_data.data darknet/cfg/yolov3_custom3.cfg backup/yolov3_custom_last.weights /content/drive/MyDrive/weeds_detection/data/agri_0_3.jpeg -thresh 0.30
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Cannot load image data/labels/32_0.png
# Cannot load image data/labels/33_0.png
# Cannot load image data/labels/34_0.png
# Cannot load image data/labels/35_0.png
# Cannot load image data/labels/36_0.png
# Cannot load image data/labels/37_0.png
# Cannot load image data/labels/38_0.png
# Cannot load image data/labels/39_0.png
# Cannot load image data/labels/40_0.png
# Cannot load image data/labels/41_0.png
# Cannot load image data/labels/42_0.png
# Cannot load image data/labels/43_0.png
# Cannot load image data/labels/44_0.png
# Cannot load image data/labels/45_0.png
# Cannot load image data/labels/46_0.png
# Cannot load image data/labels/47_0.png
# Cannot load image data/labels/48_0.png
# Cannot load image data/labels/49_0.png
# Cannot load image data/labels/50_0.png
# Cannot load image data/labels/51_0.png
# Cannot load image data/labels/52_0.png
# Cannot load image data/labels/53_0.png
# ...

# %%
# !darknet/darknet detector train data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# /bin/bash: darknet/darknet: Permission denied

# %%
import cv2

# %%
 from google.colab.patches import cv2_imshow

# %%
from keras.preprocessing.image import load_img, img_to_array

# %%
img = load_img("/content/drive/MyDrive/weeds_detection/predictions.jpg")

# %%
img_ar = img_to_array(img)

# %%
cv2_imshow(img_ar)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F525C972F50>

# %%
cd /content/drive/MyDrive/weeds_detection/backup
# Out:
# /content/drive/MyDrive/weeds_detection/backup

# %%
# !zip -r yolov3_custom_last.weights.zip .zip yolov3_custom_last.weights
# Out:
# 	zip warning: name not matched: .zip
#   adding: yolov3_custom_last.weights (deflated 7%)
